# %% [markdown]
#                              Statistics Advance Part 1

# %% [markdown]
# 1. What is a random variable in probability theory?
# - A random variable is a numerical outcome of a random process or experiment. It assigns a real number to each possible outcome in a sample space.

# %% [markdown]
# 2. What are the types of random variables?
# - Different type of random variable are :
#  - Discrete random variable: Takes countable values (e.g., 0, 1, 2, …).
#
#  - Continuous random variable: Takes any value in a continuous range (e.g., height, temperature).

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions?
# - The difference between discrete and continuous distributions are :
#  - Discrete distributions deal with discrete random variables and assign probabilities to specific values.
#
#  - Continuous distributions deal with continuous variables and use a probability density function; probabilities are determined over intervals.

# %% [markdown]
# 4. What are probability distribution functions (PDF)?
# - A Probability Distribution Function (PDF) describes the likelihood of a random variable taking specific values. For discrete variables, it's a probability mass function (PMF), and for continuous variables, it’s a probability density function (pdf).

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from PDFs?
# - PDF shows the probability of a specific value (or range for continuous).
#
# - CDF shows the cumulative probability up to a certain value:
#   F(x)=P(X≤x)

# %% [markdown]
# 6. What is a discrete uniform distribution?
# - A discrete uniform distribution assigns equal probability to all possible outcomes. Example: Rolling a fair die (each face has 1/6 chance).

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution?
# - Two outcomes: Success (1) or Failure (0)
#
# - Probability of success:𝑝,failure: 1-𝑝
# -Mean = 𝑝, Variance = 𝑝 (1-p)

# %% [markdown]
# 8. What is the binomial distribution, and how is it used in probability?
# - The binomial distribution models the number of successes in 𝑛 independent Bernoulli trials.
#
#  Formula: 𝑃(x=k)=(n/k)p^k(1−𝑝)^n-k
#
#  Used in quality control, surveys, etc.

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied?
# - The Poisson distribution models the number of events in a fixed interval of time or space, given a constant average rate λ.
#
#  Used in: call centers, traffic flow, etc.

# %% [markdown]
# 10. What is a continuous uniform distribution?
# - A continuous uniform distribution is a probability distribution where a continuous random variable has an equal probability of taking any value within a specified range (between a lower limit 'a' and an upper limit 'b'). Essentially, all outcomes within that interval are equally likely, and the probability density function is constant over that range.

# %% [markdown]
# 11. What are the characteristics of a normal distribution?
# - Characteristics of a normal distribution are :
#  - Bell-shaped and symmetric
#
#  - Mean = Median = Mode
#
#  - Defined by mean (μ) and standard deviation (σ)
#
#  - Follows the empirical rule (68-95-99.7%)

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important?
# - It’s a normal distribution with mean = 0 and standard deviation = 1.
# Important because:
#
#  - Used for calculating Z-scores
#
#  - Simplifies statistical testing and comparisons

# %% [markdown]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The CLT states that the distribution of sample means approximates a normal distribution as sample size increases, regardless of the population's distribution.
# Critical for:
#
#  - Justifying use of normal approximation
#
#  - Enabling hypothesis testing

# %% [markdown]
# 14. How does the Central Limit Theorem relate to the normal distribution?
# - It allows us to use the normal distribution to estimate the behavior of sample means, even when the underlying population is not normally distributed (as long as n is large).

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing?
# - Z-statistics are used to test hypotheses when the population variance is known and/or the sample size is large. It helps determine how far the sample mean is from the population mean in terms of standard deviations.

# %% [markdown]
# 16. How do you calculate a Z-score, and what does it represent?
# - Z-score represents how many standard deviations a data point is from the mean.
#   It is calculated by formula :
#
#     Z = X-μ/σ
#
#  Where:
#   - X = sample value
#   - μ = mean
#   - σ = standard deviation

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?
# - Point estimate: A single value estimate of a parameter (e.g., sample mean).
#
# - Interval estimate: A range within which the parameter lies, usually with a confidence level (e.g., confidence interval).

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis?
# - Confidence intervals (CI) show the range of plausible values for a population parameter and indicate the reliability of the estimate. A 95% CI means there's a 95% chance the true value lies within that interval.

# %% [markdown]
# 19. What is the relationship between a Z-score and a confidence interval?
# - Relationship between a Z-score and a confidence interval are :
#  - A Z-score measures how many standard deviations a data point is from the mean.
#  - A confidence interval provides a range of values likely to contain a population parameter.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?
# - Z-scores standardize values across different distributions by converting them to the same scale (mean = 0, SD = 1), making comparisons meaningful.

# %% [markdown]
# 21. What are the assumptions for applying the Central Limit Theorem?
# - Assumptions to apply on the Central Limit Theorem are :
#  - Independent random samples
#
#  - Identically distributed variables
#
#  - Sufficiently large sample size (typically n ≥ 30)
#
#  - Finite mean and variance

# %% [markdown]
# 22. What is the concept of expected value in a probability distribution?
# - The expected value (also known as mean or mathematical expectation) of a random variable is the long-run average value it takes over many repetitions of an experiment or trial. It gives a measure of the center of a probability distribution.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# - A probability distribution provides the probabilities for each outcome, and the expected value summarizes the average or “expected” outcome based on that distribution.

# %% [markdown]
#  #    Practical

# %%
# 1. Write a Python program to generate a random variable and display its value
import numpy as np

rv = np.random.rand()
print("Random Variable:", rv)
# Out:
# Random Variable: 0.5281686563152063

# %%
#2. What are the types of random variables.
import matplotlib.pyplot as plt
from scipy.stats import randint

x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)
plt.stem(x, pmf)
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("x")
plt.ylabel("PMF")
plt.grid()
plt.show()

# %%
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
from scipy.stats import bernoulli

def bernoulli_pdf(p):
    x = [0, 1]
    probs = bernoulli.pmf(x, p)
    return dict(zip(x, probs))

print("Bernoulli PDF (p=0.6):", bernoulli_pdf(0.6))
# Out:
# Bernoulli PDF (p=0.6): {0: np.float64(0.4000000000000001), 1: np.float64(0.6)}

# %%
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
from scipy.stats import binom
import matplotlib.pyplot as plt


data = binom.rvs(n=10, p=0.5, size=1000)
plt.hist(data, bins=11, edgecolor='black', density=True)
plt.title("Binomial Distribution Histogram")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %%
# 5. Create a Poisson distribution and visualize it using Python.
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import poisson

x = np.arange(0, 20)
pmf = poisson.pmf(x, mu=5)
plt.stem(x, pmf)
plt.title("Poisson Distribution (λ=5)")
plt.xlabel("x")
plt.ylabel("PMF")
plt.grid()
plt.show()

# %%
# 6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.cdf = randint.cdf(x, 1, 7)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint
x = np.arange(1, 7)
cdf = randint.cdf(x, 1, 7)


plt.step(x, cdf)
plt.title("CDF of Discrete Uniform Distribution")
plt.xlabel("x")
plt.ylabel("CDF")
plt.grid()
plt.show()

# %%
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

from scipy.stats import uniform

data = uniform.rvs(loc=0, scale=1, size=1000)
plt.hist(data, bins=20, edgecolor='black', density=True)
plt.title("Histogram of Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
# 8. Simulate data from a normal distribution and plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(loc=0, scale=1, size=1000)
plt.hist(data, bins=30, density=True, edgecolor='black')
plt.title("Histogram of Normal Distribution")
plt.show()

# %%
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import zscore

data = np.random.normal(10, 2, 100)
z_scores = zscore(data)
plt.plot(z_scores, marker='o')
plt.title("Z-scores of Dataset")
plt.grid()
plt.show()

# %%
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
import numpy as np
import matplotlib.pyplot as plt

samples = [np.mean(np.random.exponential(scale=2, size=30)) for _ in range(1000)]
plt.hist(samples, bins=30, density=True)
plt.title("CLT with Exponential Distribution")
plt.xlabel("Sample Mean")
plt.show()

# %%
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
samples = [np.mean(np.random.normal(loc=0, scale=1, size=30)) for _ in range(1000)]
plt.hist(samples, bins=30, density=True)
plt.title("CLT with Normal Distribution")
plt.xlabel("Sample Mean")
plt.show()

# %%
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).
from scipy.stats import norm

x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x, 0, 1)
plt.plot(x, pdf)
plt.title("Standard Normal Distribution PDF")
plt.xlabel("x")
plt.ylabel("PDF")
plt.grid()
plt.show()

# %%
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.
probs = binom.pmf(np.arange(11), n=10, p=0.5)
print("Probabilities for Binomial(n=10, p=0.5):", probs)
# Out:
# Probabilities for Binomial(n=10, p=0.5): [0.00097656 0.00976563 0.04394531 0.1171875  0.20507812 0.24609375
#  0.20507812 0.1171875  0.04394531 0.00976563 0.00097656]

# %%
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
value = 85
mean = 70
std_dev = 10
z = (value - mean) / std_dev
print(f"Z-score of {value} is {z}")
# Out:
# Z-score of 85 is 1.5

# %%
# 15. Implement hypothesis testing using Z-statistics for a sample dataset.
sample_mean = 72
pop_mean = 70
std_dev = 10
n = 30

z = (sample_mean - pop_mean) / (std_dev / np.sqrt(n))
print(f"Z-statistic: {z}")
# Out:
# Z-statistic: 1.0954451150103321

# %%
# 16. Create a confidence interval for a dataset using Python and interpret the result.
import scipy.stats as stats

data = np.random.normal(50, 5, 100)
mean = np.mean(data)
sem = stats.sem(data)
conf = stats.t.interval(0.95, len(data)-1, loc=mean, scale=sem)
print("95% Confidence Interval:", conf)
# Out:
# 95% Confidence Interval: (np.float64(49.03248871955737), np.float64(50.99554815486989))

# %%
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
data = np.random.normal(60, 8, 100)
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.t.interval(0.95, len(data)-1, loc=mean, scale=sem)
print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (np.float64(58.94652617695675), np.float64(62.16217256501196))

# %%
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x, 0, 1)
plt.plot(x, pdf)
plt.title("Normal Distribution PDF")
plt.grid()
plt.show()

# %%
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
x = np.arange(0, 20)
cdf = poisson.cdf(x, mu=4)
plt.step(x, cdf)
plt.title("CDF of Poisson Distribution (λ=4)")
plt.grid()
plt.show()

# %%
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.
a, b = 0, 10
data = np.random.uniform(a, b, 1000)
expected_value = np.mean(data)
print("Expected Value (Uniform[0,10]):", expected_value)
# Out:
# Expected Value (Uniform[0,10]): 5.09393508705342

# %%
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.
data1 = np.random.normal(10, 2, 100)
data2 = np.random.normal(10, 5, 100)

std1 = np.std(data1)
std2 = np.std(data2)

plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'])
plt.title("Comparison of Standard Deviations")
plt.show()

print("Std Dev 1:", std1, "Std Dev 2:", std2)
# Out:
# /tmp/ipython-input-28-36776521.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'])
# Std Dev 1: 2.0004483366785144 Std Dev 2: 4.251987502366144

# %%
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
data = np.random.normal(50, 10, 100)
data_range = np.max(data) - np.min(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)
print("Range:", data_range, "IQR:", iqr)
# Out:
# Range: 48.47749632734085 IQR: 14.96300970166147

# %%
# 23. Implement Z-score normalization on a dataset and visualize its transformation.

data = np.random.normal(100, 15, 100)
z_data = zscore(data)

plt.hist(z_data, bins=20)
plt.title("Z-score Normalized Data")
plt.show()

# %%
#24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.03429797370332407
# Kurtosis: -0.025724385741066502
